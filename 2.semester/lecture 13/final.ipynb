# %% [markdown]
# # Závěrečný test
# Při testu smíte používat oficiální python dokumentaci https://docs.python.org/3/ a vaše poznámky. Nikoli mé Notebooky z hodin, kamarády ani GPT.
#
# #### Jak odevzdat:
# Výsledné kódy mi pošlete na mail jan.strelecek@matfyz.cuni.cz.
#
# Můžete odevzdat buďto jeden Jupyter notebook (.ipynb) nebo pro každou úlohu jeden Python soubor (.py). Ke úloze přidávám doctest nebo další možnost jak program otestovat, můžete tak funkci rovnou sami vyzkoušet a pak odevzdat s tímto otestováním.
#
# #### Bodování:
# 1/3 za rozumné rozmyšlení, pokud napíšete pseudokód nebo okomentujete co je třeba udělat, případně detailní prompt pro nějaké fakt hloupé GPT.
# 2/3 za téměř funkční kód, kde jsou nějaké problémy ale je vidět že po chvilce debugování byste to opravili.
# 1 za funkční kód.
#
# Na úspěšné splnění je třeba získat 50% bodů.

# %% [markdown]
# # Zploštění listu (3 body)
# Napište funkci `flatten()`, která přijme jako vstup nested list integerů a vrátí list integerů. Například:
# ```python
# print(flatten([[1,2,[3]],4]))
# > [1, 2, 3, 4]
# ```

# %%
def flatten(a: list):
    """
    Flatten a nested list.
    >>> flatten([[]])
    []
    >>> flatten([[1,2,[3]],4])
    [1, 2, 3, 4]
    """

# run doctest
import doctest
doctest.testmod()

# %% [markdown]
# # Jednosměrný spojový list (3 body)
# Definujte třídu pro node jednosměrného spojového listu. Dále definujte jednosměrný spojový list s hlavou a implementujte metodu pro přidání prvku na konec listu.
# Program i s testem tedy bude vypadat takto:
# ```python
# # class pro Node
# # class pro LinkedList s metodou append
#
# l = LinkedList()
# l.append(1)
# l.append(2)
#
# print(l.head.data)
# print(l.head.next.data)
# print(l.head.next.next.data)
# ```
# Výsledek by pak něl být:
# ```python
# None
# 1
# 2
# ```
# *Připomínka: Jednosměrným spojovým listem se myslí spojový list, kde každý node obsahuje `hodnotu nodu` a `odkaz na další node`. Hlava ukazuje na první element v seznamu.*

# %% [markdown]
# # Stack (4 body)
# Zkontrolujte, zda jsou závorky ve výrazu správně. Tedy každé otevírací závorce `(`, `[`, přísluší v pořadí `)`, `]` resp. Využijte zásobníku, last-in-first-out. Můžete použít implementaci `pop()` a `append()` na objektech typu `list`.

# %%
def check_brackets(expression: str):
    """Funkce pro kontrolu závorek ve výrazu
    >>> check_brackets("([a] + 3)")
    True
    >>> check_brackets("([a] + 3")
    False
    >>> check_brackets("(]")
    False
    >>> check_brackets("([)]")
    False
    """


import doctest
doctest.testmod()
