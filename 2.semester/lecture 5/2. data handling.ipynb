# %% [markdown]
# <div style="text-align: center;">
#     <img src="panda.png" alt="Author: Fernando Revilla cc-by-sa-2.5" width="400">
# </div>

# %%
import pandas as pd

# Load the CSV file
name = "data.csv" # this takes file from the same folder, can be even a URL
df = pd.read_csv(name)

# Display the first few rows
print(df.head(3))
# Out:
#      Animal    Type  Legs     Habitat  \
# 0       Dog  Mammal     4    Domestic
# 1       Cat  Mammal     4    Domestic
# 2  Kangaroo  Mammal     2  Grasslands
#
#                                         Fun Fact
# 0            Dogs can understand human emotions!
# 1        Cats sleep for about 13-16 hours a day.
# 2  They can jump up to 3 times their own height.

# %%
# rename columns, specify data separator 
df = pd.read_csv("data.csv", names=["zvíře", "druh", "počet nohou", "prostředí", "zajímavost"], sep=",")
df
# Out:
#        zvíře       druh počet nohou   prostředí  \
# 0     Animal       Type        Legs     Habitat
# 1        Dog     Mammal           4    Domestic
# 2        Cat     Mammal           4    Domestic
# 3   Kangaroo     Mammal           2  Grasslands
# 4    Octopus    Mollusk           8       Ocean
# 5    Penguin       Bird           2   Antarctic
# 6      Sloth     Mammal           4  Rainforest
# 7  Chameleon    Reptile           4     Forests
# 8   Elephant     Mammal           4    Savannah
# 9    Axolotl  Amphibian           4       Water
#
#                                        zajímavost
# 0                                        Fun Fact
# 1             Dogs can understand human emotions!
# 2         Cats sleep for about 13-16 hours a day.
# 3   They can jump up to 3 times their own height.
# 4     Octopuses have three hearts and blue blood!
# 5  Penguins propose to their mates with a pebble.
# 6   Sloths can take up to a month to digest food!
# ...
