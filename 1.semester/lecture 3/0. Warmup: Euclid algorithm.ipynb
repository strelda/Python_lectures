# %% [markdown]
# ## Example: Euclid algorithm
#
# Find the greatest common divisor of two numbers using [Euclid algorithm](https://en.wikipedia.org/wiki/Euclidean_algorithm). Basic thought is that $gcd(a,b)=gcd(b,a\%b)$.

# %%
x = 24
y = 16

# find the greatest common divisor of numbers x, y
while x != y:
    if x > y:
        x -= y
    else:
        y -= x

print(x)

# %%
x, y = 24, 16

# find the greatest common divisor of numbers x, y
while x > 0 and y > 0:
    if x > y:
        x = x % y
    else:
        y = y % x

# the result is saved in the number which is positive
if x > 0:
    print(x)
else:
    print(y)

# %%
x, y = 24, 16

while y > 0:
    x, y = y, x%y

print(x)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Two options:
# <ol>
# <li>a) Understand the Euclid algorithm and try to write the code on your own.</li>
# <li>b) Finish one task from the last time you did not complete.</li>
# </div>
